# %%
# %run myimport.py
# Out:
# import Image numpy->np matplotlib->plt pandas->pd tushare->ts base64 pytesseract->pt success!

# %%
#创建一个图片
plt.plot(np.random.randn(30).cumsum(), 'bo--')
plt.show()

# %%
#创建多个窗口图
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))
ax3.plot(np.random.randn(500).cumsum(), 'b--')

plt.show()

# %%
#创建多个窗口图并设置图间距为0
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)  #创建多窗口图
for i in range(2):
    for j in range(3):
        axes[i, j].hist(np.random.randn(500), bins=50, color='b', alpha=0.5)
        
plt.subplots_adjust(wspace=0, hspace=0) #调整各个图之间的间距

plt.show()

# %%
#带有标记的线形图示例1
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Defalut')
plt.show()

# %%
#带有标记的线形图示例2
data = np.random.randn(30).cumsum()
plt.plot(data, 'k-', drawstyle='steps-post', label='step-post')
plt.legend(loc='best')
plt.show()

# %%
#xlim--x轴绘图范围
#说明轴的自定义，创建一个随机漫步图
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
plt.show()

# %%
#说明轴的自定义，创建一个随机漫步图-修改X轴的标签刻度标题字体大小旋转角度等
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])  #xticks修改X轴的刻度
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=10, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
plt.show()

# %%
#创建有三条线和图例的示例：图例设置方法-legends
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'b', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'g--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')
ax.text(50, 1, 'hello world!', family='monospace', fontsize=10)
ax.legend(loc='best')
plt.show()

# %%
#使用注释和箭头示例
from datetime import datetime

fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='b-')

crisis_data = [
 (datetime(2007, 10, 11), 'Peak of bull market'),
 (datetime(2008, 3, 12), 'Bear Stearns Fails'),
 (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
 ax.annotate(label, xy=(date, spx.asof(date) + 50),
 xytext=(date, spx.asof(date) + 200),
 arrowprops=dict(facecolor='green'),
 horizontalalignment='left', verticalalignment='top')
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2006', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

plt.show()

# %%
#图形示例程序 矩形 三角形 椭圆
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.25, 0.75), 0.6, 0.3, color='b', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

plt.show()

#plt.savefig('figpath.svg')
#plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

#from io import StringIO
#buffer = StringIO()
#plt.savefig(buffer)
#plot_data =buffer.getvalue()
#print plot_data

# %%
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
plt.show()

# %%
#pandas的DataFrame绘图示例
df = DataFrame(np.random.randn(10, 6).cumsum(0), columns=['A', 'B', 'C', 'D', 'E', 'F'], index=np.arange(0, 100, 10))
df.plot()
plt.show()

# %%
#柱状图
fig, axes = plt.subplots(2, 1)
data = Series(np.random.randn(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='b', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='g', alpha=0.7)
plt.show()

# %%
df = DataFrame(np.random.randint(60, 100, size=(6, 4)), index=['许巍', '刘德华', '郑智化', '罗大佑', '李宗盛', '王菲'], columns=pd.Index(['演唱', '语言', '填词', '作曲'], name='Genus'))
df
# Out:
# Genus  演唱  语言  填词  作曲
# 许巍     92  71  83  79
# 刘德华    85  66  71  78
# 郑智化    67  75  78  61
# 罗大佑    92  95  71  61
# 李宗盛    91  82  99  71
# 王菲     79  99  91  90

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
df.plot(kind='barh', stacked=True, rot=30, alpha=0.5)
plt.show()

# %%
tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# 5         25.29  4.71     No   Sun  Dinner     4
# 6          8.77  2.00     No   Sun  Dinner     2
# 7         26.88  3.12     No   Sun  Dinner     4
# 8         15.04  1.96     No   Sun  Dinner     2
# 9         14.78  3.23     No   Sun  Dinner     2
# 10        10.27  1.71     No   Sun  Dinner     2
# 11        35.26  5.00     No   Sun  Dinner     4
# 12        15.42  1.57     No   Sun  Dinner     2
# 13        18.43  3.00     No   Sun  Dinner     4
# 14        14.83  3.02     No   Sun  Dinner     2
# 15        21.58  3.92     No   Sun  Dinner     2
# 16        10.33  1.67     No   Sun  Dinner     3
# 17        16.29  3.71     No   Sun  Dinner     3
# ...

# %%
party_counts = pd.crosstab(tips.day, tips.smoker)
party_counts
# Out:
# smoker  No  Yes
# day
# Fri      4   15
# Sat     45   42
# Sun     57   19
# Thur    45   17

# %%
task = pd.read_excel('task20200402.xlsx')
#task = task.head(50)
a = task[task.taskunitdesc==u'PAMT-推送']
#task_time = pd.crosstab(task.taskunitdesc,  task.runtimebymin)
#task_time

# %%
#task_index = pd.pivot_table(task, 
#                            index=['bankcode', 'taskunitdesc'], 
#                            columns='runtimebyhour',
#                            aggfunc=[np.sum],
#                            values=['firsttaskstarttime', 'lasttaskendtime'],
#                            fill_value=0,
#                            margins=True,
#                            dropna=True
#                           )

task_index = pd.pivot_table(task, 
                            index=['taskunitdesc'], 
                            columns=[],
                            values=['firsttaskstarttime', 'lasttaskendtime', 'runtimebymin'],
                            aggfunc={'firsttaskstarttime':min, 'lasttaskendtime':max, 'runtimebymin':np.mean},
                            fill_value=0,
                            margins=True,
                            dropna=True
                           )

task_index
# Out:
#                     firsttaskstarttime      lasttaskendtime runtimebymin
# taskunitdesc
# BDSS-历史层           2020-04-03 02:01:02  2020-04-03 12:54:44      224.141
# BTFS-兵团标准化         2020-04-03 12:02:54  2020-04-03 12:02:59        1.605
# CAMS-个人结算账户        2020-04-03 06:01:04  2020-04-03 09:43:26      140.066
# CAMS-回流数据加载        2020-04-03 00:12:28  2020-04-03 00:56:46      21.2171
# CAMS-推送            2020-04-03 06:07:54  2020-04-03 09:43:04      131.789
# CBRC-非现场监管         2020-04-03 09:00:55  2020-04-03 11:09:20      29.3728
# CBRC-非现场监管-日报      2020-04-03 07:31:07  2020-04-03 10:54:25      87.1162
# CSSR-共享现金          2020-04-03 12:00:28  2020-04-03 13:19:10      56.5555
# CTRK-客户风险          2020-04-03 11:01:18  2020-04-03 11:01:20     0.326667
# CTRK-推送            2020-04-03 11:01:18  2020-04-03 11:01:21     0.336667
# DPIN-存款保险          2020-04-03 08:28:34  2020-04-03 13:18:18      16.0723
# DPIN-模型层           2020-04-03 08:18:41  2020-04-03 13:17:41      49.7008
# ...

# %%
df3 = DataFrame(np.random.randn(5, 5), rows=['a', 'b', 'c', 'd', 'e'])
df3
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-54-c32915fe54fd> in <module>()
# ----> 1 df3 = DataFrame(np.random.randn(5, 5), rows=['a', 'b', 'c', 'd', 'e'])
#       2 df3
#
# TypeError: __init__() got an unexpected keyword argument 'rows'

# %%
import matplotlib.pyplot as plt
from matplotlib.dates import DateFormatter, drange
import numpy as np
import datetime
import time
 
formatter = DateFormatter('%H:%M:%S')  # 时间表现形式，这里只显示了时分秒
a = "2020-4-2 00:00:01"
StarttimeArray = time.strptime(task_index.firsttaskstarttime[0], "%Y-%m-%d %H:%M:%S")
Starttimestamp = time.mktime(StarttimeArray)  # 时间戳
EndtimeArray = time.strptime(task_index.lasttaskendtime[0], "%Y-%m-%d %H:%M:%S")
Endtimestamp = time.mktime(EndtimeArray)  # 时间戳

# 这里测试时间戳得到datetime
d1 = datetime.datetime.fromtimestamp(Starttimestamp)
d2 = datetime.datetime.fromtimestamp(Endtimestamp) 
delta = datetime.timedelta(seconds=2)  # 以0.5秒为间隔生成时间序列
dates = drange(d1, d2, delta) 

y = task_index.index[]

#fig = plt.figure(figsize=(20,20))
#ax = fig.add_subplot(1, 1, 1)
fig, ax = plt.subplots(figsize=(10,10))
plt.plot_date(dates, s)
ax.xaxis.set_major_formatter(formatter)
ax.xaxis.set_tick_params(labelsize=10, color='black') 
plt.show()

# %%
drange?

# %%
import matplotlib.dates as mdates
xfmt = mdates.DateFormatter('%y-%m-%d %H:%M')

df = task_index
fig = plt.figure(figsize=(20,20))
ax = fig.add_subplot(1, 1, 1)
ax.xaxis.set_major_formatter(xfmt)

df.firsttaskstarttime = pd.to_datetime(df.firsttaskstarttime)
plt.plot(df['firsttaskstarttime'], df['runtimebymin'])

plt.ylabel(u'风速',fontproperties='SimHei')
plt.xlabel(u'时间',fontproperties='SimHei')

plt.grid(True)
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.dates import AutoDateLocator, DateFormatter  

df = pd.read_excel('task20200329.xlsx',  parse_dates=['firsttaskstarttime'])
pd.to_datetime(df.firsttaskstarttime)
plt.plot_date(df.firsttaskstarttime, df.runtimebymin, fmt='b.')

ax = plt.gca()
ax.xaxis.set_major_formatter(DateFormatter('%Y-%m-%d %H:%M'))  #设置时间显示格式
ax.xaxis.set_major_locator(AutoDateLocator(maxticks=24))       #设置时间间隔  

plt.xticks(rotation=50, ha='center')
label = ['timepoint']
plt.legend(label, loc='upper right')

plt.grid()

ax.set_title(u'批量作业统计图', fontproperties='SimHei',fontsize=14)  
ax.set_xlabel(u'执行时间', fontproperties='SimHei')
ax.set_ylabel(u'作业名称', fontproperties='SimHei')

plt.show()

# %%
# 3.Book Price Comparsion
left  = [0, 1, 2, 3, 4]
price = [5, 7, 9, 13, 12]

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False
plt.barh(range(5), price, height=0.5, align='center', log=True, color='red', edgecolor='blue', linewidth=1, alpha=0.5)
plt.xlabel('price')
plt.yticks(range(5),['Amazon','Dangdang','BooksChina','Jingdong','Tianmao'])
plt.xlim([5,24])
plt.title('Book Price Comparsion')
for x,y in enumerate(price):
    plt.text(y+1, x,'%s' %y,va='center')
plt.show()

# %%
# 3.Book Price Comparsion
left  = [0, 1, 2, 3, 4]
price = [5, 7, 9, 13, 12]

plt.rcParams['font.sans-serif'] = ['Microsoft YaHei']
plt.rcParams['axes.unicode_minus'] = False
plt.barh(range(5), price, height=0.5, align='center', log=True, color='red', edgecolor='blue', linewidth=1, alpha=0.5)
plt.xlabel('price')
plt.yticks(range(5),['Amazon','Dangdang','BooksChina','Jingdong','Tianmao'])
plt.xlim([5,24])
plt.title('Book Price Comparsion')
#for x,y in enumerate(price):
#    plt.text(y+1, x,'%s' %y,va='center')
plt.show()

# %%
# 外嵌图表plt.table()
# table(cellText=None, cellColours=None,cellLoc='right', colWidths=None,rowLabels=None, rowColours=None, rowLoc='left',
# colLabels=None, colColours=None, colLoc='center',loc='bottom', bbox=None)

data = [[ 66386, 174296,  75131, 577908,  32015],
        [ 58230, 381139,  78045,  99308, 160454],
        [ 89135,  80552, 152558, 497981, 603535],
        [ 78415,  81858, 150656, 193263,  69638],
        [139361, 331509, 343164, 781380,  52269]]
columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail')
rows = ['%d year' % x for x in (100, 50, 20, 10, 5)]
df = pd.DataFrame(data,columns = ('Freeze', 'Wind', 'Flood', 'Quake', 'Hail'),
                 index = ['%d year' % x for x in (100, 50, 20, 10, 5)])
print(df)

df.plot(kind='barh',grid = True,colormap='Blues_r',stacked=True,figsize=(8,3))
# 创建堆叠图

plt.table(cellText = data,
          cellLoc='center',
          cellColours = None,
          rowLabels = rows,
          rowColours = plt.cm.BuPu(np.linspace(0, 0.5,5))[::-1],  # BuPu可替换成其他colormap
          colLabels = columns,
          colColours = plt.cm.Reds(np.linspace(0, 0.5,5))[::-1], 
          rowLoc='right',
          loc='bottom')
# cellText：表格文本
# cellLoc：cell内文本对齐位置
# rowLabels：行标签
# colLabels：列标签
# rowLoc：行标签对齐位置
# loc：表格位置 → left，right，top，bottom

plt.xticks([])
# 不显示x轴标注
plt.show()
# Out:
#           Freeze    Wind   Flood   Quake    Hail
# 100 year   66386  174296   75131  577908   32015
# 50 year    58230  381139   78045   99308  160454
# 20 year    89135   80552  152558  497981  603535
# 10 year    78415   81858  150656  193263   69638
# 5 year    139361  331509  343164  781380   52269

# %%
for i in range(dflen):
    StarttimeArray = time.strptime(startTime[i], "%Y-%m-%d %H:%M:%S")
    startNum[i] = time.mktime(StarttimeArray)  # 时间戳
    EndtimeArray = time.strptime(endTime[i], "%Y-%m-%d %H:%M:%S")
    endNum[i] = time.mktime(EndtimeArray)  # 时间戳
    #pfrlist.append(pfr) 
df = pd.DataFrame(task_index, columns = ('startNum', 'endNum'),
                 index = task_index.index)

# %%
df.plot(kind='barh',grid = True,colormap='Blues_r',stacked=True,figsize=(8,3))
# 创建堆叠图

plt.table(cellText = data,
          cellLoc='center',
          cellColours = None,
          rowLabels = rows,
          rowColours = plt.cm.BuPu(np.linspace(0, 0.5,5))[::-1],  # BuPu可替换成其他colormap
          colLabels = columns,
          colColours = plt.cm.Reds(np.linspace(0, 0.5,5))[::-1], 
          rowLoc='right',
          loc='bottom')
# cellText：表格文本
# cellLoc：cell内文本对齐位置
# rowLabels：行标签
# colLabels：列标签
# rowLoc：行标签对齐位置
# loc：表格位置 → left，right，top，bottom

plt.xticks([])
# 不显示x轴标注
plt.show()

# %%
x=np.arange(5)
x
# Out:
# array([0, 1, 2, 3, 4])

# %%
import matplotlib.pyplot as plt
import numpy as np

x=np.arange(5)
#数据集
y1=[20,44,21,64,46]
y2=[10,37,24,41,40]
#误差列表
std_err1=[1,2,5,3,2]
std_err2=[2,4,3,1,2]
tick_label=['blue','jazz','pure','pop','classic']

error_params1=dict(elinewidth=3,ecolor='midnightblue',capsize=4)#设置误差标记参数
error_params2=dict(elinewidth=3,ecolor='orangered',capsize=4)#设置误差标记参数

#绘制柱状图，设置误差标记以及柱状图标签
plt.bar(x,y1,color='khaki',yerr=std_err1,error_kw=error_params1,label='tag A')
plt.bar(x,y2,bottom=y1,color='slateblue',yerr=std_err1,error_kw=error_params2,label='tag B')

plt.xticks(x,tick_label)#设置x轴的标签
#设置网格
plt.grid(True,axis='both',ls=':',color='r',alpha=0.3)

plt.legend()
#显示图形
plt.show()

# %%
StarttimeArray = time.strptime("2020-04-03 00:00:00", "%Y-%m-%d %H:%M:%S")
baseTime = time.mktime(StarttimeArray)
x=np.arange(baseTime, baseTime+(24*3600), 3600)
x
# Out:
# array([  1.58584320e+09,   1.58584680e+09,   1.58585040e+09,
#          1.58585400e+09,   1.58585760e+09,   1.58586120e+09,
#          1.58586480e+09,   1.58586840e+09,   1.58587200e+09,
#          1.58587560e+09,   1.58587920e+09,   1.58588280e+09,
#          1.58588640e+09,   1.58589000e+09,   1.58589360e+09,
#          1.58589720e+09,   1.58590080e+09,   1.58590440e+09,
#          1.58590800e+09,   1.58591160e+09,   1.58591520e+09,
#          1.58591880e+09,   1.58592240e+09,   1.58592600e+09])

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['font.sans-serif'] = ['SimHei']
fig = plt.figure(figsize=(10,5))
x=np.arange(25)
y=np.arange(5)
#数据集
startTime=[5,7,9,11,12]
endTime=[9,10,11,12,15]
tick_labelX=['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00', '24:00']
tick_labelY=[u'接口层作业',u'历史层作业',u'模型层作业',u'汇总层作业',u'报送层作业']

#绘制柱状图，设置误差标记以及柱状图标签
plt.barh(y, startTime,  color='white', align='center', label=u'开始时间')
plt.barh(y, endTime, left=startTime, color='slateblue', align='center', label=u'完成时间')

plt.xticks(x,tick_labelX, rotation=30)#设置x轴的标签
plt.yticks(y,tick_labelY)#设置y轴的标签

#设置网格
plt.grid(True,axis='both',ls=':',color='r',alpha=0.5)

plt.legend()
#显示图形
plt.show()

# %%
# 外嵌图表plt.table()
# table(cellText=None, cellColours=None,cellLoc='right', colWidths=None,rowLabels=None, rowColours=None, rowLoc='left',
# colLabels=None, colColours=None, colLoc='center',loc='bottom', bbox=None)
task_index
plt.rcParams['font.sans-serif'] = ['SimHei']
startTime = task_index[['firsttaskstarttime']]
endTime   = task_index[['lasttaskendtime']]
startNum  = []
endNum    = []
dflen = task_index.shape[0]
StarttimeArray = time.strptime("2020-04-03 00:00:00", "%Y-%m-%d %H:%M:%S")
baseTime = time.mktime(StarttimeArray)

for i in range(dflen):
    starttimeArray = '';
    EndtimeArray = '';
    StarttimeArray = time.strptime(startTime['firsttaskstarttime'][i], "%Y-%m-%d %H:%M:%S")
    startNum.append(time.mktime(StarttimeArray)- baseTime)  
    EndtimeArray = time.strptime(endTime['lasttaskendtime'][i], "%Y-%m-%d %H:%M:%S")
    endNum.append(time.mktime(EndtimeArray) - time.mktime(StarttimeArray))  
    #print "===%d, %s" %(i, StarttimeArray, startNum[i])
    
task_index['startNum']=pd.Series(startNum,index=task_index.index) 
task_index['endNum']=pd.Series(endNum,index=task_index.index) 

df = pd.DataFrame(task_index, columns = ('startNum', 'endNum'),
                 index = task_index.index)

df = df[:dflen-1]
df = df.sort_index(by=['startNum','endNum'], ascending=False)

# 创建堆叠图
df.plot(kind='barh',grid = True, color=('white', 'blue'), stacked=True, figsize=(20,15), alpha=0.5)
ax = plt.gca()

#设置X轴坐标
x=np.arange(0, 24*3600, 3600)
tick_labelX=['00:00', '01:00', '02:00', '03:00', '04:00', '05:00', '06:00', '07:00', '08:00', '09:00', '10:00', '11:00', '12:00', '13:00', '14:00', '15:00', '16:00', '17:00', '18:00', '19:00', '20:00', '21:00', '22:00', '23:00', '24:00']
plt.xticks(x,tick_labelX, rotation=30)#设置x轴的标签

ax.set_title(u'批量作业统计图', fontproperties='SimHei',fontsize=14)  
ax.set_xlabel(u'执行时间', fontproperties='SimHei')
ax.set_ylabel(u'作业名称', fontproperties='SimHei')

#plt.barh(range(5), price, height=0.5, align='center', log=True, color='red', edgecolor='blue', linewidth=1, alpha=0.5)

#plt.yticks(df.index, fontproperties='SimHei',fontsize=10)
#plt.show()
plt.savefig("/root/task0403.jpg")
# Out:
# /root/anaconda2/lib/python2.7/site-packages/ipykernel_launcher.py:30: FutureWarning: by argument to sort_index is deprecated, pls use .sort_values(by=...)

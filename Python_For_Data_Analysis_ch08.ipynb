# %%
# %run myimport.py
# Out:
# import Image numpy->np matplotlib->plt pandas->pd tushare->ts base64 pytesseract->pt success!

# %%
#创建一个图片
plt.plot(np.random.randn(30).cumsum(), 'bo--')
plt.show()

# %%
#创建多个窗口图
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30)+3*np.random.randn(30))
ax3.plot(np.random.randn(500).cumsum(), 'b--')

plt.show()

# %%
#创建多个窗口图并设置图间距为0
fig, axes = plt.subplots(2, 3, sharex=True, sharey=True)  #创建多窗口图
for i in range(2):
    for j in range(3):
        axes[i, j].hist(np.random.randn(500), bins=50, color='b', alpha=0.5)
        
plt.subplots_adjust(wspace=0, hspace=0) #调整各个图之间的间距

plt.show()

# %%
#带有标记的线形图示例1
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Defalut')
plt.show()

# %%
#带有标记的线形图示例2
data = np.random.randn(30).cumsum()
plt.plot(data, 'k-', drawstyle='steps-post', label='step-post')
plt.legend(loc='best')
plt.show()

# %%
#xlim--x轴绘图范围
#说明轴的自定义，创建一个随机漫步图
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
plt.show()

# %%
#说明轴的自定义，创建一个随机漫步图-修改X轴的标签刻度标题字体大小旋转角度等
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())
ticks = ax.set_xticks([0, 250, 500, 750, 1000])  #xticks修改X轴的刻度
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'], rotation=10, fontsize='small')
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')
plt.show()

# %%
#创建有三条线和图例的示例：图例设置方法-legends
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum(), 'b', label='one')
ax.plot(np.random.randn(1000).cumsum(), 'g--', label='two')
ax.plot(np.random.randn(1000).cumsum(), 'r.', label='three')
ax.text(50, 1, 'hello world!', family='monospace', fontsize=10)
ax.legend(loc='best')
plt.show()

# %%
#使用注释和箭头示例
from datetime import datetime

fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)
data = pd.read_csv('spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='b-')

crisis_data = [
 (datetime(2007, 10, 11), 'Peak of bull market'),
 (datetime(2008, 3, 12), 'Bear Stearns Fails'),
 (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
 ax.annotate(label, xy=(date, spx.asof(date) + 50),
 xytext=(date, spx.asof(date) + 200),
 arrowprops=dict(facecolor='green'),
 horizontalalignment='left', verticalalignment='top')
# Zoom in on 2007-2010
ax.set_xlim(['1/1/2006', '1/1/2011'])
ax.set_ylim([600, 1800])
ax.set_title('Important dates in 2008-2009 financial crisis')

plt.show()

# %%
#图形示例程序 矩形 三角形 椭圆
fig = plt.figure();
ax = fig.add_subplot(1, 1, 1)

rect = plt.Rectangle((0.25, 0.75), 0.6, 0.3, color='b', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]], color='g', alpha=0.5)

ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

plt.show()

#plt.savefig('figpath.svg')
#plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

#from io import StringIO
#buffer = StringIO()
#plt.savefig(buffer)
#plot_data =buffer.getvalue()
#print plot_data

# %%
s = Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
s.plot()
plt.show()

# %%
#pandas的DataFrame绘图示例
df = DataFrame(np.random.randn(10, 6).cumsum(0), columns=['A', 'B', 'C', 'D', 'E', 'F'], index=np.arange(0, 100, 10))
df.plot()
plt.show()

# %%
#柱状图
fig, axes = plt.subplots(2, 1)
data = Series(np.random.randn(16), index=list('abcdefghijklmnop'))
data.plot(kind='bar', ax=axes[0], color='b', alpha=0.7)
data.plot(kind='barh', ax=axes[1], color='g', alpha=0.7)
plt.show()

# %%
df = DataFrame(np.random.randint(60, 100, size=(6, 4)), index=['许巍', '刘德华', '郑智化', '罗大佑', '李宗盛', '王菲'], columns=pd.Index(['演唱', '语言', '填词', '作曲'], name='Genus'))
df
# Out:
# Genus  演唱  语言  填词  作曲
# 许巍     92  71  83  79
# 刘德华    85  66  71  78
# 郑智化    67  75  78  61
# 罗大佑    92  95  71  61
# 李宗盛    91  82  99  71
# 王菲     79  99  91  90

# %%
plt.rcParams['font.sans-serif']=['SimHei'] #用来正常显示中文标签
plt.rcParams['axes.unicode_minus']=False #用来正常显示负号
df.plot(kind='barh', stacked=True, rot=30, alpha=0.5)
plt.show()

# %%
tips = pd.read_csv('tips.csv')
tips
# Out:
#      total_bill   tip smoker   day    time  size
# 0         16.99  1.01     No   Sun  Dinner     2
# 1         10.34  1.66     No   Sun  Dinner     3
# 2         21.01  3.50     No   Sun  Dinner     3
# 3         23.68  3.31     No   Sun  Dinner     2
# 4         24.59  3.61     No   Sun  Dinner     4
# 5         25.29  4.71     No   Sun  Dinner     4
# 6          8.77  2.00     No   Sun  Dinner     2
# 7         26.88  3.12     No   Sun  Dinner     4
# 8         15.04  1.96     No   Sun  Dinner     2
# 9         14.78  3.23     No   Sun  Dinner     2
# 10        10.27  1.71     No   Sun  Dinner     2
# 11        35.26  5.00     No   Sun  Dinner     4
# 12        15.42  1.57     No   Sun  Dinner     2
# 13        18.43  3.00     No   Sun  Dinner     4
# 14        14.83  3.02     No   Sun  Dinner     2
# 15        21.58  3.92     No   Sun  Dinner     2
# 16        10.33  1.67     No   Sun  Dinner     3
# 17        16.29  3.71     No   Sun  Dinner     3
# ...

# %%
party_counts = pd.crosstab(tips.day, tips.smoker)
party_counts
# Out:
# smoker  No  Yes
# day
# Fri      4   15
# Sat     45   42
# Sun     57   19
# Thur    45   17

# %%
task = pd.read_excel('task20200329.xlsx')
task = task.head(50)
task[task.taskunitdesc==u'BDSS-历史层']
#task_time = pd.crosstab(task.taskunitdesc,  task.runtimebymin)
#task_time
# Out:
#    bankcode            taskunitname taskunitdesc             workdate  \
# 0     12057  XT0189_12057_flow_BDSS     BDSS-历史层  2020-03-29 00:00:00
# 26    12081  XT0189_12081_flow_BDSS     BDSS-历史层  2020-03-29 00:00:00
#
#           planstarttime            starttime              endtime  \
# 0   2020-03-30 05:00:00  2020-03-30 05:00:33  2020-03-30 08:51:25
# 26  2020-03-30 05:00:00  2020-03-30 05:00:35  2020-03-30 09:06:40
#
#    runtimebyhour  runtimebymin     status   firsttaskstarttime  \
# 0      3小时50分52秒        230.87  COMPLETED  2020-03-30 05:00:56
# 26       4小时6分5秒        246.08  COMPLETED  2020-03-30 05:01:00
#
#         lasttaskendtime
# 0   2020-03-30 08:51:24
# 26  2020-03-30 09:06:40

# %%
#task_index = pd.pivot_table(task, 
#                            index=['bankcode', 'taskunitdesc'], 
#                            columns='runtimebyhour',
#                            aggfunc=[np.sum],
#                            values=['firsttaskstarttime', 'lasttaskendtime'],
#                            fill_value=0,
#                            margins=True,
#                            dropna=True
#                           )

task_index = pd.pivot_table(task, 
                            index=['taskunitdesc'], 
                            columns=[],
                            values=['firsttaskstarttime', 'lasttaskendtime'],
                            aggfunc={'firsttaskstarttime':min, 'lasttaskendtime':max},
                            fill_value=0,
                            margins=True,
                            dropna=True
                           )

task_index
# Out:
#                 firsttaskstarttime      lasttaskendtime
# taskunitdesc
# BDSS-历史层       2020-03-30 05:00:56  2020-03-30 09:06:40
# CAMS-个人结算账户    2020-03-30 06:06:10  2020-03-30 08:37:00
# CAMS-回流数据加载    2020-03-30 00:25:54  2020-03-30 00:46:44
# CAMS-推送        2020-03-30 07:50:52  2020-03-30 08:36:33
# CBRC-非现场监管     2020-03-30 08:50:53  2020-03-30 09:12:30
# CBRC-非现场监管-日报  2020-03-30 08:45:22  2020-03-30 09:12:17
# CSSR-共享现金      2020-03-30 12:01:00  2020-03-30 12:42:39
# DPIN-存款保险      2020-03-30 12:01:00  2020-03-30 12:12:34
# DPIN-模型层       2020-03-30 12:31:13  2020-03-30 12:49:41
# DUT-mysql卸数    2020-03-30 00:10:39  2020-03-30 00:12:08
# EAST-银监标准化     2020-03-30 12:01:20  2020-03-30 12:01:59
# EAST_CHECK     2020-03-30 12:02:50  2020-03-30 12:03:10
# FSSS-金融报送      2020-03-30 08:45:22  2020-03-30 09:10:03
# INFC-接口层       2020-03-30 04:30:54  2020-03-30 09:06:24
# MODU-模型层       2020-03-30 07:28:06  2020-03-30 09:06:18
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import numpy as np
% matplotlib inline
import datetime#这个包很关键
#设定开始和结束时间
start=datetime.time(0,0)
stop=datetime.time(23,59)
delta=datetime.timedelta(minutes=1)#设定日期的间隔
dates=mpl.dates.drange(start,stop,delta)# 返回浮点型的日期序列，这个是生成时间序列，同理如果是将序列转成日期呢？
values=np.random.rand(len(dates))
#存在两个问题，一个是坐标轴没有按照日期的形式去标注，另一个是刻度的数量和位置也不合适
fig=plt.figure(figsize=(24,12))#调整画图空间的大小
plt.plot(dates,values,linestyle='-',marker='*',c='r',alpha=0.5)#作图
ax=plt.gca()
date_format=mpl.dates.DateFormatter('%Y-%m-%d')#设定显示的格式形式
ax.xaxis.set_major_formatter(date_format)#设定x轴主要格式
ax.xaxis.set_major_locator(mpl.ticker.MultipleLocator(30))#设定坐标轴的显示的刻度间隔
fig.autofmt_xdate()#防止x轴上的数据重叠，自动调整。

plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-113-b888290e3ddf> in <module>()
#       8 stop=datetime.time(23,59)
#       9 delta=datetime.timedelta(minutes=1)#设定日期的间隔
# ---> 10 dates=mpl.dates.drange(start,stop,delta)# 返回浮点型的日期序列，这个是生成时间序列，同理如果是将序列转成日期呢？
#      11 values=np.random.rand(len(dates))
#      12 #存在两个问题，一个是坐标轴没有按照日期的形式去标注，另一个是刻度的数量和位置也不合适
#
# /usr/lib/python2.7/site-packages/matplotlib-2.0.2-py2.7-linux-x86_64.egg/matplotlib/dates.pyc in drange(dstart, dend, delta)
#     413     :class:`datetime.timedelta` instance.
#     414     """
# --> 415     f1 = _to_ordinalf(dstart)
#     416     f2 = _to_ordinalf(dend)
#     417     step = delta.total_seconds() / SEC_PER_DAY
#
# /usr/lib/python2.7/site-packages/matplotlib-2.0.2-py2.7-linux-x86_64.egg/matplotlib/dates.pyc in _to_ordinalf(dt)
#     218         tzi = UTC
#     219
# ...

# %%
datetime.timedelta
